# %%
Name=Shivraj Pandurrang Mane
Roll No=55 
Class=TE-AIDS
prac-02

# %%
# importing libraries 
import numpy as np

# %%
# function of checking thresold value 
def linear_threshold_gate(dot, T):
    '''Returns the binary threshold output'''
    if dot >= T:
        return 1
    else:
        return 0

# %%
# matrix of inputs
input_table = np.array([
[0,0], # both no
[0,1], # one no, one yes 
[1,0], # one yes, one no
[1,1] # bot yes
])
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[5], line 2
#       1 # matrix of inputs
# ----> 2 input_table = np.array([
#       3 [0,0], # both no
#       4 [0,1], # one no, one yes
#       5 [1,0], # one yes, one no
#       6 [1,1] # bot yes
#       7 ])
#
# NameError: name 'np' is not defined

# %%
print(f'input table:\n{input_table}')
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(f'input table:\n{input_table}')
#
# NameError: name 'input_table' is not defined

# %%
weights = np.array([1,-1])
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 weights = np.array([1,-1])
#
# NameError: name 'np' is not defined

# %%
dot_products = input_table @ weights
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dot_products = input_table @ weights
#
# NameError: name 'input_table' is not defined

# %%
print('output:')
T = 1
for i in range(0,4):
    activation = linear_threshold_gate(dot_products[i], T)
    print(f'Activation: {activation}')
# Out:
# output:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[9], line 4
#       2 T = 1
#       3 for i in range(0,4):
# ----> 4     activation = linear_threshold_gate(dot_products[i], T)
#       5     print(f'Activation: {activation}')
#
# NameError: name 'dot_products' is not defined
